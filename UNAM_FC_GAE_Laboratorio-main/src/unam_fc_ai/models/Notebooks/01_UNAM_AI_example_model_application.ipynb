# %% [markdown]
# <center>
#
# $\Huge \textbf{Universidad Nacional Autónoma de México}$
# $\Huge \textbf{Facultad de Ciencias}$
# <p align="center">
#   <img src="https://www.ingenieria.unam.mx/nuestra_facultad/images/institucionales/escudos/escudounam_azul.jpg" alt="Tecmilenio" width="200"/>
# </p>
#
# <hr style="height:3px; background-color:#0B6E4F; border:none;"/>
#
#
# $\LARGE \textbf{Inteligencia Artificial}$
#
# $\Large \textit{Ejemplo de la aplicación de un modelo}$
#
#
# \begin{array}{rl}
# \textbf{Docente:} & Dra. Jessica Sarahi Méndez Rincón \\[6pt]
# \textbf{Ayudante de laboratorio:} & Diego   Eduardo Peña Villegas \\[6pt]
# \textbf{Fecha de realización:} & 25/01/2026
# \end{array}
#
# </center>

# %% [markdown]
# # Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os

import matplotlib.pyplot as plt

# 1. Detectamos la ubicación actual del notebook
current_path = os.getcwd()

# 1. Definir la ruta base en Drive (Asegúrate que el nombre
#coincida con tu carpeta)
# Si la carpeta está en la raíz de Drive, se ve así:
DRIVE_PATH = '/content/drive/MyDrive/Colab Notebooks/UNAM/UNAM_FC_JSMR_Laboratorio'

# 2. Subimos un nivel para llegar a la raíz y luego entramos a 'src'


# 3. Agregamos 'src' al buscador de Python (sys.path)
if os.path.exists(DRIVE_PATH):
    os.chdir(DRIVE_PATH)
    # 2. Agregar 'src' al sistema para importar unam_fc_ai
    src_path = os.path.join(DRIVE_PATH, 'src')
    if src_path not in sys.path:
        sys.path.append(src_path)
    print(f"✅ Conectado a Drive. Ruta actual: {os.getcwd()}")
else:
    print("❌ Error: No se encontró la carpeta en Drive. Verifica el nombre.")

# 4. Ahora sí, la importación funcionará perfectamente
try:
    from unam_fc_ai.models.regression import linear_regression
    print("🚀 Librería unam_fc_ai importada con éxito.")
    # Definición de datos de prueba (DEV)
    # Ejemplo: Relación entre horas de estudio (X) y calificación (Y)
    horas_estudio = [1, 2, 3, 4, 5, 6, 8, 10]
    calificaciones = [5, 5.5, 6, 6.8, 7, 7.5, 8.8, 9.5]

    print("--- Iniciando Cálculo de Regresión Lineal OLS ---")

    # Invocamos la función de nuestro motor 'unam_fc_ai'
    # Nota: Al ejecutar esto, verás el reporte de tiempo y memoria en la salida
    intercepto_a, pendiente_b = linear_regression(horas_estudio, calificaciones)

    print(f"\n✅ Modelo Entrenado:")
    print(f"La ecuación es: y = {intercepto_a:.4f} + {pendiente_b:.4f}x")

    # Ejemplo de predicción
    nueva_hora = 7
    prediccion = intercepto_a + (pendiente_b * nueva_hora)
    print(f"\n💡 Predicción: Si estudias {nueva_hora} horas, tu calificación estimada es {prediccion:.2f}")




    plt.figure(figsize=(8, 5))
    plt.scatter(horas_estudio, calificaciones, color='#003b5c', label='Datos Reales')
    y_linea = [intercepto_a + pendiente_b * x for x in horas_estudio]
    plt.plot(horas_estudio, y_linea, color='#d4af37', label='Línea de Regresión')
    plt.title("Relación Horas vs Calificación (UNAM AI Lab)")
    plt.xlabel("Horas de Estudio")
    plt.ylabel("Calificación")
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()
except ImportError as e:
    print(f"❌ Error de importación: {e}")
# Out:
# ✅ Conectado a Drive. Ruta actual: /content/drive/MyDrive/Colab Notebooks/UNAM/UNAM_FC_JSMR_Laboratorio
# 🚀 Librería unam_fc_ai importada con éxito.
# --- Iniciando Cálculo de Regresión Lineal OLS ---
#
# ========================================
# 📊 UNAM AI PERFORMANCE REPORT: Linear Regression
# ----------------------------------------
# ⏱️ Execution Time: 0.00003910 sec
# 💾 RAM Storage:    464 bytes
# ========================================
#
#
# ✅ Modelo Entrenado:
# La ecuación es: y = 4.5243 + 0.5104x
#
# 💡 Predicción: Si estudias 7 horas, tu calificación estimada es 8.10

# %% [markdown]
# # Visual Studio Code

# %%
import sys
import os
import matplotlib.pyplot as plt

# 1. Detectamos la ubicación actual del notebook
current_path = os.getcwd()

# 2. Subimos un nivel para llegar a la raíz y luego entramos a 'src'
# Esto funciona tanto en VS Code local como en Google Colab
project_root = os.path.abspath(os.path.join(current_path, '..'))
src_path = os.path.join(project_root, 'src')

# 3. Agregamos 'src' al buscador de Python (sys.path)
if src_path not in sys.path:
    sys.path.append(src_path)
    print(f"✅ Ambiente DEV configurado. Buscando librería en: {src_path}")

# 4. Ahora sí, la importación funcionará perfectamente
try:
    from unam_fc_ai.models.regression import linear_regression
    print("🚀 Librería unam_fc_ai importada con éxito.")
except ImportError as e:
    print(f"❌ Error de importación: {e}")


# Definición de datos de prueba (DEV)
# Ejemplo: Relación entre horas de estudio (X) y calificación (Y)
horas_estudio = [1, 2, 3, 4, 5, 6, 8, 10]
calificaciones = [5, 5.5, 6, 6.8, 7, 7.5, 8.8, 9.5]

print("--- Iniciando Cálculo de Regresión Lineal OLS ---")

# Invocamos la función de nuestro motor 'unam_fc_ai'
# Nota: Al ejecutar esto, verás el reporte de tiempo y memoria en la salida
intercepto_a, pendiente_b = linear_regression(horas_estudio, calificaciones)

print(f"\n✅ Modelo Entrenado:")
print(f"La ecuación es: y = {intercepto_a:.4f} + {pendiente_b:.4f}x")

# Ejemplo de predicción
nueva_hora = 7
prediccion = intercepto_a + (pendiente_b * nueva_hora)
print(f"\n💡 Predicción: Si estudias {nueva_hora} horas, tu calificación estimada es {prediccion:.2f}")






plt.figure(figsize=(8, 5))
plt.scatter(horas_estudio, calificaciones, color='#003b5c', label='Datos Reales')
y_linea = [intercepto_a + pendiente_b * x for x in horas_estudio]
plt.plot(horas_estudio, y_linea, color='#d4af37', label='Línea de Regresión')
plt.title("Relación Horas vs Calificación (UNAM AI Lab)")
plt.xlabel("Horas de Estudio")
plt.ylabel("Calificación")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# ✅ Ambiente DEV configurado. Buscando librería en: d:\UNAM\2026 Enero Agosto\Inteligencia Artificial\UNAM_FC_JSMR_Laboratorio\src
# 🚀 Librería unam_fc_ai importada con éxito.
# --- Iniciando Cálculo de Regresión Lineal OLS ---
#
# ========================================
# 📊 UNAM AI PERFORMANCE REPORT: Linear Regression
# ----------------------------------------
# ⏱️ Execution Time: 0.00001950 sec
# 💾 RAM Storage:    464 bytes
# ========================================
#
#
# ✅ Modelo Entrenado:
# La ecuación es: y = 4.5243 + 0.5104x
#
# 💡 Predicción: Si estudias 7 horas, tu calificación estimada es 8.10

# %% [markdown]
# <hr/>
# <footer style="text-align:center; font-size:12px; color:gray;">
# © 2026 UNAM Facultado de Ciencias – Todos los derechos reservados
#
# </footer>
